# %%
# ────────────────────────────────────────────────────────────────
# 4_models.ipynb  ·  Mixture‐of‐Experts training & automated tuning
# ─────────────────────────────────────────────────────────────────────────────

# 0) Ensure src/ is on PYTHONPATH
# %run setup.py

import time
import numpy as np
import pandas as pd
import random
import torch
from pathlib import Path
from itertools import combinations
from src.pretrained_models import save_gate, load_gate, _subset_key
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import log_loss

# need to delete corrupted cache files
import shutil  

from src.logs import log_event, LogKind

# Set random seeds for reproducibility
SEED = 13
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# ────────────────────────────────────────────────────────────────
# EXPERIMENT CONFIG
# ────────────────────────────────────────────────────────────────
GATE_LR     = 1e-3         # <– change to your new LR
GATE_EPOCHS = 1           # <– change to your new number of epochs
EXP_NAME    = f"lr{GATE_LR}_ep{GATE_EPOCHS}"

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 1) Load train/valid splits (no changes)
# ─────────────────────────────────────────────────────────────────────────────
DATA_DIR = Path("../data/splits")
train_df = pd.read_csv(DATA_DIR / "train.csv").dropna(subset=["question1", "question2"])
valid_df = pd.read_csv(DATA_DIR / "valid.csv").dropna(subset=["question1", "question2"])

pairs_tr  = list(zip(train_df.question1, train_df.question2))
y_tr      = train_df.is_duplicate.values.astype(int)
pairs_val = list(zip(valid_df.question1, valid_df.question2))
y_val     = valid_df.is_duplicate.values.astype(int)

# %%
# ────────────────────────────────────────────────────────────────
# 2) Ensure necessary directories exist
# ────────────────────────────────────────────────────────────────
PRETRAINED_DIR = Path("../models/pretrained")
CUSTOM_DIR     = Path("../models/custom")
FEATURES_DIR   = Path("../models/features")

CACHE_DIR = Path("../models/pred_cache")
GATE_ROOT  = Path("../models/gates")
GATE_DIR  = GATE_ROOT  / EXP_NAME

for d in [PRETRAINED_DIR, CUSTOM_DIR, FEATURES_DIR, GATE_DIR, CACHE_DIR]:
    d.mkdir(parents=True, exist_ok=True)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 3) Import all experts
# ─────────────────────────────────────────────────────────────────────────────
from src.pretrained_models import (
    BertExpert,
    RobertaExpert,
    XLNetExpert,
    QuoraDistilExpert,
    CrossEncExpert,
    MoEClassifier,
    get_predictions
)
from src.custom_models import (
    LRFeatureExpert,
    XGBFeatureExpert,
    LGBMFeatureExpert,
    KNNFeatureExpert,
    RFFeatureExpert,
    SVMFeatureExpert
)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 4) Instantiate & fit feature-based experts if not already fit
# ─────────────────────────────────────────────────────────────────────────────
print(">>> Initializing classical feature-based experts…")

# We need qid1/qid2 in train_df for QuoraDistilExpert.fit(...) and for build_features(...) in custom experts
meta = pd.read_csv("../data/processed/question_meta.csv")
rev  = {q: i for i, q in enumerate(meta.question)}
train_df = train_df.assign(
    qid1=lambda d: d.question1.map(rev).astype(int),
    qid2=lambda d: d.question2.map(rev).astype(int),
)

# Loop through each custom‐expert class at once
feature_expert_classes = [
    LRFeatureExpert,
    XGBFeatureExpert,
    LGBMFeatureExpert,
    KNNFeatureExpert,
    RFFeatureExpert,
    SVMFeatureExpert
]

feature_experts = []
for cls in feature_expert_classes:
    expert = cls(dim=384)   # uses IPCA‐reduced 384‐dim by default
    if not expert.model_path.exists():
        print(f"   * Fitting {cls.__name__} on IPCA‐384 features…")
        t0 = time.time()
        expert.fit(train_df, y_tr)
        elapsed = time.time() - t0
        print(f"     -> {cls.__name__} trained in {elapsed:.1f}s.")
        log_event(
            LogKind.MODEL,
            model=cls.__name__,
            phase="fit",
            seconds=round(elapsed, 2),
            src_dims=meta.shape[1]
        )
    else:
        print(f"   * {cls.__name__} pickle found—skipping training.")
        log_event(
            LogKind.MODEL,
            model=cls.__name__,
            phase="load",
            seconds=0.0,
            src_dims=meta.shape[1]
        )
    feature_experts.append(expert)
# Out:
# >>> Initializing classical feature-based experts…
#    * LRFeatureExpert pickle found—skipping training.
#    * XGBFeatureExpert pickle found—skipping training.
#    * LGBMFeatureExpert pickle found—skipping training.
#    * KNNFeatureExpert pickle found—skipping training.
#    * RFFeatureExpert pickle found—skipping training.
#    * SVMFeatureExpert pickle found—skipping training.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 5) Load and configure pretrained experts
# ─────────────────────────────────────────────────────────────────────────────
print("\n>>> Initializing Hugging‐Face experts…")

EMB_PATH = "../data/processed/question_embeddings_768.npy"
LR_PATH  = PRETRAINED_DIR / "quoradistil_lr.pkl"

hf_experts = [BertExpert(), RobertaExpert()]
try:
    xl = XLNetExpert()
    hf_experts.append(xl)
except RuntimeError:
    print("   * Skipping XLNetExpert (sentencepiece not installed).")

quora_exp = QuoraDistilExpert(emb_path=EMB_PATH, lr_path=str(LR_PATH))
hf_experts.append(quora_exp)
hf_experts.append(CrossEncExpert())

# Only fit QuoraDistilExpert’s LR head if pickle is missing
if not quora_exp.lr_path.exists():
    print("   * Training QuoraDistilExpert LR head on 768‐dim pairs…")
    t0 = time.time()
    quora_exp.fit(
        train_df.qid1.values.astype(int),
        train_df.qid2.values.astype(int),
        y_tr
    )
    elapsed = time.time() - t0
    print(f"     -> QuoraDistilExpert LR trained in {elapsed:.1f}s.")
    log_event(
        LogKind.MODEL,
        model="QuoraDistilExpert",
        phase="fit",
        seconds=round(elapsed, 2),
        src_dims=1536
    )
else:
    print("   * QuoraDistilExpert LR already present—skipping LR training.")
    log_event(
        LogKind.MODEL,
        model="QuoraDistilExpert",
        phase="load",
        seconds=0.0,
        src_dims=1536
    )
# Out:
# >>> Initializing Hugging‐Face experts…
#    * Skipping XLNetExpert (sentencepiece not installed).
#    * QuoraDistilExpert LR already present—skipping LR training.

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 6) Combine all experts & clean out any stale pred_cache files
# ─────────────────────────────────────────────────────────────────────────────
experts = hf_experts + feature_experts
print(f"\nTotal experts = {len(experts)}\n   – " +
      "\n   – ".join([e.__class__.__name__ for e in experts]))

def clean_cache_if_needed(pairs, split_tag):
    """
    Delete any pred_cache/<split_tag>_*.npy whose row-count != len(pairs).
    This prevents mismatched‐shape errors.
    """
    for fpath in sorted(CACHE_DIR.glob(f"{split_tag}_*.npy")):
        arr = np.load(fpath, mmap_mode="r")
        if arr.shape[0] != len(pairs):
            print(f"[WARNING] {fpath.name} has {arr.shape[0]} rows (expected {len(pairs)}). Deleting.")
            fpath.unlink()

clean_cache_if_needed(pairs_tr, "train")
clean_cache_if_needed(pairs_val, "valid")

# Now that any bad files are deleted, we can safely (re)compute missing predictions
print("\n>>> Caching predictions for each expert…")
t0 = time.time()
P_tr  = get_predictions(experts, pairs_tr,  "train", cache_dir=CACHE_DIR)
P_val = get_predictions(experts, pairs_val, "valid", cache_dir=CACHE_DIR)
elapsed = time.time() - t0
print(f"   * Forward-passes & caching completed in {elapsed:.1f}s.")
print(f"   * Shapes: P_tr={P_tr.shape}, P_val={P_val.shape}")
# Out:
# Total experts = 10
#    – BertExpert
#    – RobertaExpert
#    – QuoraDistilExpert
#    – CrossEncExpert
#    – LRFeatureExpert
#    – XGBFeatureExpert
#    – LGBMFeatureExpert
#    – KNNFeatureExpert
#    – RFFeatureExpert
#    – SVMFeatureExpert
#
# >>> Caching predictions for each expert…
#    * Forward-passes & caching completed in 0.0s.
#    * Shapes: P_tr=(323613, 10), P_val=(40710, 10)

# %%
# ────────────────────────────────────────────────────────────────
# 7) Gate tuning over VALID split
# ────────────────────────────────────────────────────────────────
device       = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def fit_gate_from_preds(
    moe: MoEClassifier,
    P_tr_sub: np.ndarray,
    y_tr: np.ndarray,
    P_val_sub: np.ndarray,
    y_val: np.ndarray
) -> float:
    """
    Train `moe.gate` on precomputed columns and return validation log-loss.
    """
    ds = TensorDataset(
        torch.tensor(P_tr_sub, dtype=torch.float32).to(device),
        torch.tensor(y_tr,      dtype=torch.float32).to(device),
    )
    loader = DataLoader(ds, batch_size=1024, shuffle=True)

    for epoch in range(1, moe.epochs + 1):
        last_loss = 0.0
        for probs, targets in loader:
            weights = moe.gate(probs)
            blended = (weights * probs).sum(1).clamp(0.0, 1.0)
            loss    = moe.loss_fn(blended, targets)

            moe.opt.zero_grad()
            loss.backward()
            moe.opt.step()
            last_loss = loss.item()

        print(f"Epoch {epoch}/{moe.epochs} · last-batch loss {last_loss:.4f}")

    with torch.no_grad():
        probs_val   = torch.tensor(P_val_sub, dtype=torch.float32).to(device)
        blended_val = (moe.gate(probs_val) * probs_val).sum(1)
    return log_loss(y_val, blended_val.cpu().numpy())


print("\n>>> Gate tuning over VALID split…")

# build all non-empty subsets of expert-indices
idx_of = {e.__class__.__name__: i for i, e in enumerate(experts)}
valid_subsets = [
    subset for k in range(1, len(experts)+1)
           for subset in combinations(idx_of.values(), k)
]

best_ll, best_subset = float("inf"), None
subset_results = []

for idxs in valid_subsets:
    subset_exps  = [experts[i] for i in idxs]
    key          = _subset_key(subset_exps)
    ckpt_path    = GATE_DIR / f"gate_{key}.pt"

    P_tr_sub  = P_tr[:, idxs]
    P_val_sub = P_val[:, idxs]

    print("-" * 80)
    if ckpt_path.exists():
        # load existing gate
        start = time.time()
        moe = load_gate(subset_exps, ckpt_path)
        load_time = time.time() - start
        phase = "load"
        print(f"LOADED gate for {key} in {load_time:.1f}s")
        # eval
        with torch.no_grad():
            probs_val   = torch.tensor(P_val_sub, dtype=torch.float32).to(device)
            blended_val = (moe.gate(probs_val) * probs_val).sum(1)
        ll = log_loss(y_val, blended_val.cpu().numpy())
    else:
        # train new gate
        moe = MoEClassifier(subset_exps, lr=GATE_LR, epochs=GATE_EPOCHS)
        print(f"TRAINING gate for {key} …")
        ll = fit_gate_from_preds(moe, P_tr_sub, y_tr, P_val_sub, y_val)
        save_gate(moe, ckpt_path)
        phase = "fit"
        print(f" -> trained & saved gate_{key}.pt  · valid LL={ll:.4f}")

    # log & record
    log_event(
        LogKind.GATE,
        model=f"Gate_{key}",
        phase=phase,
        seconds=round(ll, 4),           # we log LL in "seconds" field to keep consistent columns
        valid_log_loss=round(ll, 4)
    )
    print(f"{phase.upper():6} {key:<50} valid LL={ll:.4f}\n")

    subset_results.append((idxs, ll))
    if ll < best_ll:
        best_ll, best_subset = ll, idxs

print(f"\n>>> BEST subset {best_subset} · valid LL = {best_ll:.4f}")
# Out:
# >>> Gate tuning over VALID split…
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert in 0.0s
# LOAD   BertExpert                                         valid LL=0.1015
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert in 0.0s
# LOAD   RobertaExpert                                      valid LL=0.0557
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert in 0.0s
# LOAD   QuoraDistilExpert                                  valid LL=0.6962
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert in 0.0s
# LOAD   CrossEncExpert                                     valid LL=0.2387
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert in 0.0s
# LOAD   LRFeatureExpert                                    valid LL=0.6588
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert                                   valid LL=0.6134
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert                                  valid LL=0.6127
#
# --------------------------------------------------------------------------------
# LOADED gate for KNNFeatureExpert in 0.0s
# LOAD   KNNFeatureExpert                                   valid LL=0.9034
#
# --------------------------------------------------------------------------------
# LOADED gate for RFFeatureExpert in 0.0s
# LOAD   RFFeatureExpert                                    valid LL=0.6352
#
# --------------------------------------------------------------------------------
# LOADED gate for SVMFeatureExpert in 0.0s
# LOAD   SVMFeatureExpert                                   valid LL=0.6280
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert in 0.0s
# LOAD   BertExpert+RobertaExpert                           valid LL=0.0399
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert                       valid LL=0.2574
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert                          valid LL=0.1195
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert                         valid LL=0.1357
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+XGBFeatureExpert                        valid LL=0.1712
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+LGBMFeatureExpert                       valid LL=0.2649
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+KNNFeatureExpert                        valid LL=0.3238
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RFFeatureExpert                         valid LL=0.2078
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+SVMFeatureExpert                        valid LL=0.1543
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert                    valid LL=0.1659
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert                       valid LL=0.0682
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert                      valid LL=0.2512
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+XGBFeatureExpert in 0.0s
# LOAD   RobertaExpert+XGBFeatureExpert                     valid LL=0.1389
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LGBMFeatureExpert in 0.0s
# LOAD   RobertaExpert+LGBMFeatureExpert                    valid LL=0.0792
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+KNNFeatureExpert                     valid LL=0.5611
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+RFFeatureExpert                      valid LL=0.1584
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+SVMFeatureExpert                     valid LL=0.0818
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert                   valid LL=0.2559
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert                  valid LL=0.6267
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+XGBFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+XGBFeatureExpert                 valid LL=0.5568
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LGBMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LGBMFeatureExpert                valid LL=0.5600
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+KNNFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+KNNFeatureExpert                 valid LL=0.5918
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+RFFeatureExpert                  valid LL=0.5639
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+SVMFeatureExpert                 valid LL=0.5805
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert                     valid LL=0.2496
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   CrossEncExpert+XGBFeatureExpert                    valid LL=0.3504
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LGBMFeatureExpert                   valid LL=0.3168
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   CrossEncExpert+KNNFeatureExpert                    valid LL=0.4965
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   CrossEncExpert+RFFeatureExpert                     valid LL=0.3057
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+SVMFeatureExpert                    valid LL=0.3020
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+XGBFeatureExpert                   valid LL=0.6201
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+LGBMFeatureExpert                  valid LL=0.6135
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+KNNFeatureExpert                   valid LL=0.6185
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+RFFeatureExpert                    valid LL=0.5981
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+SVMFeatureExpert                   valid LL=0.6297
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+LGBMFeatureExpert                 valid LL=0.6123
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+KNNFeatureExpert                  valid LL=0.6488
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+RFFeatureExpert                   valid LL=0.6029
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+SVMFeatureExpert                  valid LL=0.6161
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+KNNFeatureExpert                 valid LL=0.6659
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+RFFeatureExpert                  valid LL=0.6010
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+SVMFeatureExpert                 valid LL=0.6132
#
# --------------------------------------------------------------------------------
# LOADED gate for KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   KNNFeatureExpert+RFFeatureExpert                   valid LL=0.6617
#
# --------------------------------------------------------------------------------
# LOADED gate for KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   KNNFeatureExpert+SVMFeatureExpert                  valid LL=0.6491
#
# --------------------------------------------------------------------------------
# LOADED gate for RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RFFeatureExpert+SVMFeatureExpert                   valid LL=0.5967
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert         valid LL=0.0878
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert            valid LL=0.0505
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert           valid LL=0.1033
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+XGBFeatureExpert          valid LL=0.0908
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LGBMFeatureExpert         valid LL=0.0765
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+KNNFeatureExpert          valid LL=0.3886
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+RFFeatureExpert           valid LL=0.1058
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+SVMFeatureExpert          valid LL=0.0945
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert        valid LL=0.1414
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+LRFeatureExpert       valid LL=0.2072
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+XGBFeatureExpert      valid LL=0.2165
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+LGBMFeatureExpert     valid LL=0.1819
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+KNNFeatureExpert      valid LL=0.4120
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+RFFeatureExpert       valid LL=0.1962
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+SVMFeatureExpert      valid LL=0.2117
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+LRFeatureExpert          valid LL=0.2007
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+XGBFeatureExpert         valid LL=0.1751
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+LGBMFeatureExpert        valid LL=0.1480
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+KNNFeatureExpert         valid LL=0.3955
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+RFFeatureExpert          valid LL=0.1829
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+SVMFeatureExpert         valid LL=0.1773
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert+XGBFeatureExpert        valid LL=0.3534
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert+LGBMFeatureExpert       valid LL=0.2412
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert+KNNFeatureExpert        valid LL=0.3642
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert+RFFeatureExpert         valid LL=0.1721
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+LRFeatureExpert+SVMFeatureExpert        valid LL=0.2405
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+XGBFeatureExpert+LGBMFeatureExpert      valid LL=0.2924
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+XGBFeatureExpert+KNNFeatureExpert       valid LL=0.3287
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+XGBFeatureExpert+RFFeatureExpert        valid LL=0.2705
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+XGBFeatureExpert+SVMFeatureExpert       valid LL=0.1821
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+LGBMFeatureExpert+KNNFeatureExpert      valid LL=0.3644
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+LGBMFeatureExpert+RFFeatureExpert       valid LL=0.2206
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+LGBMFeatureExpert+SVMFeatureExpert      valid LL=0.2671
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+KNNFeatureExpert+RFFeatureExpert        valid LL=0.3344
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+KNNFeatureExpert+SVMFeatureExpert       valid LL=0.2573
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RFFeatureExpert+SVMFeatureExpert        valid LL=0.2347
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert     valid LL=0.0784
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+LRFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+LRFeatureExpert    valid LL=0.0869
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+XGBFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+XGBFeatureExpert   valid LL=0.0956
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+LGBMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+LGBMFeatureExpert  valid LL=0.1785
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+KNNFeatureExpert   valid LL=0.3619
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+RFFeatureExpert    valid LL=0.1127
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+SVMFeatureExpert   valid LL=0.1445
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+LRFeatureExpert       valid LL=0.0843
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+XGBFeatureExpert      valid LL=0.0896
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+LGBMFeatureExpert     valid LL=0.0959
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+KNNFeatureExpert      valid LL=0.1198
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+RFFeatureExpert       valid LL=0.1072
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+SVMFeatureExpert      valid LL=0.2268
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert+XGBFeatureExpert     valid LL=0.1480
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert+LGBMFeatureExpert    valid LL=0.1894
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert+KNNFeatureExpert     valid LL=0.3079
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert+RFFeatureExpert      valid LL=0.2474
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+LRFeatureExpert+SVMFeatureExpert     valid LL=0.1600
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   RobertaExpert+XGBFeatureExpert+LGBMFeatureExpert   valid LL=0.1815
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+XGBFeatureExpert+KNNFeatureExpert    valid LL=0.2573
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+XGBFeatureExpert+RFFeatureExpert     valid LL=0.2106
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+XGBFeatureExpert+SVMFeatureExpert    valid LL=0.1858
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   RobertaExpert+LGBMFeatureExpert+KNNFeatureExpert   valid LL=0.2113
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+LGBMFeatureExpert+RFFeatureExpert    valid LL=0.2392
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+LGBMFeatureExpert+SVMFeatureExpert   valid LL=0.1963
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+KNNFeatureExpert+RFFeatureExpert     valid LL=0.2246
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+KNNFeatureExpert+SVMFeatureExpert    valid LL=0.1868
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+RFFeatureExpert+SVMFeatureExpert     valid LL=0.2299
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+LRFeatureExpert   valid LL=0.2847
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert  valid LL=0.3249
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+LGBMFeatureExpert valid LL=0.2741
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+KNNFeatureExpert  valid LL=0.3767
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+RFFeatureExpert   valid LL=0.3360
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+SVMFeatureExpert  valid LL=0.2752
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert valid LL=0.5820
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert valid LL=0.5751
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert+KNNFeatureExpert valid LL=0.6416
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert+RFFeatureExpert  valid LL=0.5794
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LRFeatureExpert+SVMFeatureExpert valid LL=0.5836
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+XGBFeatureExpert+LGBMFeatureExpert valid LL=0.5561
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+XGBFeatureExpert+KNNFeatureExpert valid LL=0.6304
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+XGBFeatureExpert+RFFeatureExpert valid LL=0.5765
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+XGBFeatureExpert+SVMFeatureExpert valid LL=0.5643
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LGBMFeatureExpert+KNNFeatureExpert valid LL=0.6339
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LGBMFeatureExpert+RFFeatureExpert valid LL=0.5624
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+LGBMFeatureExpert+SVMFeatureExpert valid LL=0.5641
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.6338
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.6086
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.5754
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert+XGBFeatureExpert    valid LL=0.2819
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert   valid LL=0.3297
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert+KNNFeatureExpert    valid LL=0.3782
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert+RFFeatureExpert     valid LL=0.3802
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LRFeatureExpert+SVMFeatureExpert    valid LL=0.2792
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert  valid LL=0.2837
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   CrossEncExpert+XGBFeatureExpert+KNNFeatureExpert   valid LL=0.5467
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   CrossEncExpert+XGBFeatureExpert+RFFeatureExpert    valid LL=0.3543
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+XGBFeatureExpert+SVMFeatureExpert   valid LL=0.3208
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LGBMFeatureExpert+KNNFeatureExpert  valid LL=0.4035
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LGBMFeatureExpert+RFFeatureExpert   valid LL=0.2751
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+LGBMFeatureExpert+SVMFeatureExpert  valid LL=0.3190
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   CrossEncExpert+KNNFeatureExpert+RFFeatureExpert    valid LL=0.6081
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+KNNFeatureExpert+SVMFeatureExpert   valid LL=0.5660
#
# --------------------------------------------------------------------------------
# LOADED gate for CrossEncExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   CrossEncExpert+RFFeatureExpert+SVMFeatureExpert    valid LL=0.3486
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert valid LL=0.6149
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert  valid LL=0.6093
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+XGBFeatureExpert+RFFeatureExpert   valid LL=0.6010
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+XGBFeatureExpert+SVMFeatureExpert  valid LL=0.6158
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert valid LL=0.6386
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+LGBMFeatureExpert+RFFeatureExpert  valid LL=0.5955
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+LGBMFeatureExpert+SVMFeatureExpert valid LL=0.6161
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+KNNFeatureExpert+RFFeatureExpert   valid LL=0.6369
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+KNNFeatureExpert+SVMFeatureExpert  valid LL=0.6351
#
# --------------------------------------------------------------------------------
# LOADED gate for LRFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LRFeatureExpert+RFFeatureExpert+SVMFeatureExpert   valid LL=0.5953
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert valid LL=0.6002
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert valid LL=0.5956
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+LGBMFeatureExpert+SVMFeatureExpert valid LL=0.6125
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert  valid LL=0.6400
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.6494
#
# --------------------------------------------------------------------------------
# LOADED gate for XGBFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   XGBFeatureExpert+RFFeatureExpert+SVMFeatureExpert  valid LL=0.6066
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.6675
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.6052
#
# --------------------------------------------------------------------------------
# LOADED gate for LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.5935
#
# --------------------------------------------------------------------------------
# LOADED gate for KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert  valid LL=0.6185
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert valid LL=0.1050
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert valid LL=0.1050
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+XGBFeatureExpert valid LL=0.1238
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LGBMFeatureExpert valid LL=0.1184
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+KNNFeatureExpert valid LL=0.2712
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+RFFeatureExpert valid LL=0.0828
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+SVMFeatureExpert valid LL=0.1914
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert valid LL=0.0857
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert valid LL=0.0752
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LGBMFeatureExpert valid LL=0.0607
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+KNNFeatureExpert valid LL=0.2398
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+RFFeatureExpert valid LL=0.1004
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+SVMFeatureExpert valid LL=0.0906
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+XGBFeatureExpert valid LL=0.0934
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+LGBMFeatureExpert valid LL=0.1419
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+KNNFeatureExpert valid LL=0.2127
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+RFFeatureExpert valid LL=0.1398
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+SVMFeatureExpert valid LL=0.1482
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+XGBFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+XGBFeatureExpert+LGBMFeatureExpert valid LL=0.1120
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+XGBFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+XGBFeatureExpert+KNNFeatureExpert valid LL=0.1898
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+XGBFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+XGBFeatureExpert+RFFeatureExpert valid LL=0.0833
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+XGBFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+XGBFeatureExpert+SVMFeatureExpert valid LL=0.1011
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LGBMFeatureExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LGBMFeatureExpert+KNNFeatureExpert valid LL=0.1952
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LGBMFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LGBMFeatureExpert+RFFeatureExpert valid LL=0.1282
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LGBMFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LGBMFeatureExpert+SVMFeatureExpert valid LL=0.1274
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.3018
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.2843
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.1568
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert valid LL=0.1709
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert valid LL=0.2142
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LGBMFeatureExpert valid LL=0.1820
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+KNNFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+KNNFeatureExpert valid LL=0.3704
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+RFFeatureExpert valid LL=0.1876
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+SVMFeatureExpert valid LL=0.1741
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert valid LL=0.2744
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert valid LL=0.2269
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LRFeatureExpert+KNNFeatureExpert in 0.0s
# ...
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.2055
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.2401
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.1446
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2329
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2868
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3055
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.2551
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.2169
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.1808
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2297
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2916
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2547
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2592
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.3403
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.2901
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2315
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.5033
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3754
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3490
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.4447
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3106
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.3557
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.3835
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.1788
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2938
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2758
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2871
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2854
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2727
#
# --------------------------------------------------------------------------------
# LOADED gate for QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.4346
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert valid LL=0.2482
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+SVMFeatureExpert valid LL=0.1733
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.1508
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3066
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2930
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2720
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2571
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2277
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3244
#
# --------------------------------------------------------------------------------
# LOADED gate for RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.3573
#
# --------------------------------------------------------------------------------
# LOADED gate for BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert in 0.0s
# LOAD   BertExpert+RobertaExpert+QuoraDistilExpert+CrossEncExpert+LRFeatureExpert+XGBFeatureExpert+LGBMFeatureExpert+KNNFeatureExpert+RFFeatureExpert+SVMFeatureExpert valid LL=0.2614
#
#
# >>> BEST subset (0, 1) · valid LL = 0.0399

# %%
# ────────────────────────────────────────────────────────────────
# 8) Retrain TOP-10 gates on Train+Valid & save final checkpoints
# ────────────────────────────────────────────────────────────────
print("\n>>> Retraining TOP-10 gates on Train+Valid…")

top10 = sorted(subset_results, key=lambda x: x[1])[:10]
P_tv  = np.vstack([P_tr, P_val])
y_tv  = np.concatenate([y_tr, y_val])

for rank, (idxs, _) in enumerate(top10, start=1):
    subset_exps = [experts[i] for i in idxs]
    key         = _subset_key(subset_exps)

    ckpt_path = GATE_DIR / f"gate_{key}_retrained_{EXP_NAME}.pt"
    idx_path  = GATE_DIR / f"moe_{key}_idxs_{EXP_NAME}.npy"

    P_sub = P_tv[:, idxs]

    moe = MoEClassifier(subset_exps, lr=GATE_LR, epochs=GATE_EPOCHS)
    ll_tv = fit_gate_from_preds(
        moe,
        P_tr_sub = P_sub[: len(y_tr)],
        y_tr     = y_tr,
        P_val_sub= P_sub[len(y_tr):],
        y_val    = y_val
    )

    save_gate(moe, ckpt_path)
    np.save(idx_path, np.array(idxs))

    log_event(LogKind.GATE, model=f"FinalGate_{key}", phase="fit",
              seconds=round(ll_tv,4), valid_log_loss=round(ll_tv,4))

    print(f"[{rank}/10] {key:<55}  ->  valid LL={ll_tv:.4f}  |  saved -> {ckpt_path.name}")
# Out:
# >>> Retraining TOP-10 gates on Train+Valid…
# Epoch 1/1 · last-batch loss 0.0122
# [1/10] BertExpert+RobertaExpert                                 ->  valid LL=0.0498  |  saved -> gate_BertExpert+RobertaExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.0474
# [2/10] BertExpert+RobertaExpert+CrossEncExpert                  ->  valid LL=0.0461  |  saved -> gate_BertExpert+RobertaExpert+CrossEncExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.2499
# [3/10] RobertaExpert                                            ->  valid LL=0.0557  |  saved -> gate_RobertaExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.0742
# [4/10] BertExpert+RobertaExpert+CrossEncExpert+LGBMFeatureExpert  ->  valid LL=0.1082  |  saved -> gate_BertExpert+RobertaExpert+CrossEncExpert+LGBMFeatureExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.0273
# [5/10] RobertaExpert+CrossEncExpert                             ->  valid LL=0.0498  |  saved -> gate_RobertaExpert+CrossEncExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.1007
# [6/10] BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert  ->  valid LL=0.0928  |  saved -> gate_BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.0682
# [7/10] BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert+RFFeatureExpert  ->  valid LL=0.1001  |  saved -> gate_BertExpert+RobertaExpert+CrossEncExpert+XGBFeatureExpert+RFFeatureExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.0542
# [8/10] BertExpert+RobertaExpert+LGBMFeatureExpert               ->  valid LL=0.0748  |  saved -> gate_BertExpert+RobertaExpert+LGBMFeatureExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.1211
# [9/10] RobertaExpert+QuoraDistilExpert+CrossEncExpert           ->  valid LL=0.0825  |  saved -> gate_RobertaExpert+QuoraDistilExpert+CrossEncExpert_retrained_lr0.001_ep1.pt
# Epoch 1/1 · last-batch loss 0.1887
# [10/10] RobertaExpert+LGBMFeatureExpert                          ->  valid LL=0.2200  |  saved -> gate_RobertaExpert+LGBMFeatureExpert_retrained_lr0.001_ep1.pt
